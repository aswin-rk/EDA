# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:\\Users\\Admin\\Downloads\\Automobile.csv')

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
print('Number of rows: ',df.shape[0])
print('Number of columns: ',df.shape[1])
# Out:
# Number of rows:  201
# Number of columns:  26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
df.describe().T
# Out:
#                    count          mean          std      min      25%  \
# symboling          201.0      0.840796     1.254802    -2.00     0.00
# normalized_losses  201.0    125.189055    33.572966    65.00   101.00
# wheel_base         201.0     98.797015     6.066366    86.60    94.50
# length             201.0    174.200995    12.322175   141.10   166.80
# width              201.0     65.889055     2.101471    60.30    64.10
# height             201.0     53.766667     2.447822    47.80    52.00
# curb_weight        201.0   2555.666667   517.296727  1488.00  2169.00
# engine_size        201.0    126.875622    41.546834    61.00    98.00
# bore               201.0      3.329701     0.268166     2.54     3.15
# stroke             201.0      3.261741     0.317875     2.07     3.11
# compression_ratio  201.0     10.164279     4.004965     7.00     8.60
# horsepower         201.0    103.263682    37.389372    48.00    70.00
# ...

# %%
df.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %%
for i in df.select_dtypes(include=np.number):
    sns.boxplot(df[i])
    plt.show()

# %%
for i in df.select_dtypes(include=np.number):
    sns.distplot(df[i])
    plt.show()

# %%
df['price'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['price'],y=df['make'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='make'>

# %%
sns.boxplot(x=df['price'],y=df['fuel_type'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='fuel_type'>

# %%
sns.violinplot(y='price',x='fuel_type',data=df)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='price'>

# %%
df['city_mpg'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.scatterplot(x=df['price'],y=df['city_mpg'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='city_mpg'>

# %%
sns.boxplot(x=df['number_of_cylinders'],y=df['city_mpg'])
# Out:
# <AxesSubplot:xlabel='number_of_cylinders', ylabel='city_mpg'>

# %%
sns.barplot(x=df['number_of_cylinders'],y=df['price'])
# Out:
# <AxesSubplot:xlabel='number_of_cylinders', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=df['number_of_cylinders'],y=df['price'],hue=df['body_style'])
# Out:
# <AxesSubplot:xlabel='number_of_cylinders', ylabel='price'>

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
